# %% [markdown]
# # Creating and Backtesting Fibonacci Strategies
#
# > _the price tend to correct it self on Fibonacci's form_

# %% [markdown]
# ---

# %% [markdown]
# # Getting the Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use("seaborn-v0_8")

# %%
data = pd.read_csv("../Data/EURUSD_ohlc.csv", parse_dates = [0], index_col = 0)
data
# Out:
#                Open     High      Low    Close
# 2008-01-01  1.45905  1.47502  1.45885  1.47146
# 2008-01-02  1.47146  1.47812  1.46876  1.47510
# 2008-01-03  1.47504  1.48254  1.46958  1.47429
# 2008-01-05  1.47451  1.47559  1.47430  1.47465
# 2008-01-06  1.47465  1.47560  1.46586  1.46954
# ...             ...      ...      ...      ...
# 2020-12-23  1.21873  1.22158  1.21774  1.21849
# 2020-12-27  1.21892  1.22504  1.21812  1.22152
# 2020-12-28  1.22145  1.22752  1.22086  1.22502
# 2020-12-29  1.22508  1.23102  1.22495  1.23000
# 2020-12-30  1.22979  1.23094  1.22094  1.22156
#
# [3811 rows x 4 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3811 entries, 2008-01-01 to 2020-12-30
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    3811 non-null   float64
#  1   High    3811 non-null   float64
#  2   Low     3811 non-null   float64
#  3   Close   3811 non-null   float64
# dtypes: float64(4)
# memory usage: 148.9 KB

# %%
data.Close.plot(figsize = (12, 8), title = "EUR/USD", fontsize = 12)
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# # A first Intuition on Fibonacci Retracement (Uptrend)

# %% [markdown]
# __Uptrend: Higher Highs and Higher Lows__

# %%
data
# Out:
#                Open     High      Low    Close
# 2008-01-01  1.45905  1.47502  1.45885  1.47146
# 2008-01-02  1.47146  1.47812  1.46876  1.47510
# 2008-01-03  1.47504  1.48254  1.46958  1.47429
# 2008-01-05  1.47451  1.47559  1.47430  1.47465
# 2008-01-06  1.47465  1.47560  1.46586  1.46954
# ...             ...      ...      ...      ...
# 2020-12-23  1.21873  1.22158  1.21774  1.21849
# 2020-12-27  1.21892  1.22504  1.21812  1.22152
# 2020-12-28  1.22145  1.22752  1.22086  1.22502
# 2020-12-29  1.22508  1.23102  1.22495  1.23000
# 2020-12-30  1.22979  1.23094  1.22094  1.22156
#
# [3811 rows x 4 columns]

# %%
data.loc["05-2010":"08-2011", "Close"].plot(figsize = (12, 8), title = "EUR/USD", fontsize = 12)
plt.hlines(y = 1.26, xmin = "06-2010", xmax = "06-2011", color = "green", label = "Retracement/Support")
plt.legend(fontsize = 12)
plt.show()

# %% [markdown]
# __Retracement__: After having reached a Higher High in an Uptrend, the __price temporarily returns (retraces) part way back__ to the previous price level before the Uptrend continues. -> __Support at Retracement Level(s)__

# %%
high = data.loc["06-2010":"08-2010", "Close"].max()
high
# Out:
# 1.32942

# %%
low = data.loc["06-2010":"08-2010", "Close"].min()
low
# Out:
# 1.19236

# %%
fifty_percent = (low + high)/2
fifty_percent
# Out:
# 1.26089

# %% [markdown]
# __Compute the retreincment lines: Fibonacci Levels derived from Fibonacci numbers: 23.6%, 38.2%, 61.8%__

# %%
fibonacci1 = 0.236
R1 = high - (high-low) * fibonacci1
R1
# Out:
# 1.2970738400000001

# %%
fibonacci2 = 0.382
R2 = high - (high-low) * fibonacci2
R2
# Out:
# 1.27706308

# %%
fibonacci3 = 0.618
R3 = high - (high-low) * fibonacci3
R3
# Out:
# 1.2447169200000001

# %%
data.loc["05-2010":"08-2011", "Close"].plot(figsize = (12, 8), title = "EUR/USD", fontsize = 12)
plt.hlines(y = 1.26, xmin = "06-2010", xmax = "06-2011", color = "green", label = "Actual Retracement/Support")
plt.hlines(y = R1, xmin = "06-2010", xmax = "06-2011", color = "red", label = "R1 (23.6%)")
plt.hlines(y = R2, xmin = "06-2010", xmax = "06-2011", color = "grey", label = "R2 (38.2%)")
plt.hlines(y = R3, xmin = "06-2010", xmax = "06-2011", color = "purple", label = "R3 (61.8%)")
plt.legend(fontsize = 12)
plt.show()

# %% [markdown]
# __Retracement Level Breakout__: If the price breaks through Retracement Level(s), this could indicate a Trend Reversal (Downtrend)

# %% [markdown]
# ---

# %% [markdown]
# ## A first Intuition on Fibonacci Retracement (Downtrend)

# %% [markdown]
# __Downtrend: Lower Lows and Lower Highs__

# %%
data
# Out:
#                Open     High      Low    Close
# 2008-01-01  1.45905  1.47502  1.45885  1.47146
# 2008-01-02  1.47146  1.47812  1.46876  1.47510
# 2008-01-03  1.47504  1.48254  1.46958  1.47429
# 2008-01-05  1.47451  1.47559  1.47430  1.47465
# 2008-01-06  1.47465  1.47560  1.46586  1.46954
# ...             ...      ...      ...      ...
# 2020-12-23  1.21873  1.22158  1.21774  1.21849
# 2020-12-27  1.21892  1.22504  1.21812  1.22152
# 2020-12-28  1.22145  1.22752  1.22086  1.22502
# 2020-12-29  1.22508  1.23102  1.22495  1.23000
# 2020-12-30  1.22979  1.23094  1.22094  1.22156
#
# [3811 rows x 4 columns]

# %%
data.loc["10-2011":"12-2012", "Close"].plot(figsize = (12, 8), title = "EUR/USD", fontsize = 12)
plt.hlines(y = 1.35, xmin = "10-2011", xmax = "12-2012", color = "red", label = "Retracement/Resistance")
plt.legend(fontsize = 12)
plt.show()

# %% [markdown]
# __Retracement__: After having reached a Lower Low in an Downtrend, the __price temporarily returns (retraces) part way back__ to the previous price level before the Downtrend continues. -> __Resistance at Retracement Level(s)__

# %%
low = data.loc["10-2011":"03-2012", "Close"].min()
low
# Out:
# 1.26377

# %%
high = data.loc["10-2011":"03-2012", "Close"].max()
high
# Out:
# 1.41886

# %%
print(fibonacci1, fibonacci2, fibonacci3)
# Out:
# 0.236 0.382 0.618

# %%
R1 = high - (high-low) * (1-fibonacci1)
R1
# Out:
# 1.30037124

# %%
R2 = high - (high-low) * (1-fibonacci2)
R2
# Out:
# 1.32301438

# %%
R3 = high - (high-low) * (1-fibonacci3)
R3
# Out:
# 1.35961562

# %%
data.loc["10-2011":"12-2012", "Close"].plot(figsize = (12, 8), title = "EUR/USD", fontsize = 12)
plt.hlines(y = 1.35, xmin = "10-2011", xmax = "12-2012", color = "red", label = "Actual Retracement/Resistance")
plt.hlines(y = R1, xmin = "10-2011", xmax = "12-2012", color = "green", label = "R1 (23.6%)")
plt.hlines(y = R2, xmin = "10-2011", xmax = "12-2012", color = "grey", label = "R2 (38.2%)")
plt.hlines(y = R3, xmin = "10-2011", xmax = "12-2012", color = "purple", label = "R3 (61.8%)")
plt.legend(fontsize = 12)
plt.show()

# %% [markdown]
# __Retracement Level Breakout__: If the price breaks through Retracement Level(s), this could indicate a Trend Reversal (Uptrend)

# %% [markdown]
# ---

# %% [markdown]
# # Identifying Local Highs
#
# - We are going to try identigiying local highs.
#
# > It can be powerfull, because if we success to identify the local highs, it can be signal to short position, for exampl.

# %%
from scipy.signal import argrelextrema

# %%
data
# Out:
#                Open     High      Low    Close
# 2008-01-01  1.45905  1.47502  1.45885  1.47146
# 2008-01-02  1.47146  1.47812  1.46876  1.47510
# 2008-01-03  1.47504  1.48254  1.46958  1.47429
# 2008-01-05  1.47451  1.47559  1.47430  1.47465
# 2008-01-06  1.47465  1.47560  1.46586  1.46954
# ...             ...      ...      ...      ...
# 2020-12-23  1.21873  1.22158  1.21774  1.21849
# 2020-12-27  1.21892  1.22504  1.21812  1.22152
# 2020-12-28  1.22145  1.22752  1.22086  1.22502
# 2020-12-29  1.22508  1.23102  1.22495  1.23000
# 2020-12-30  1.22979  1.23094  1.22094  1.22156
#
# [3811 rows x 4 columns]

# %%
hh = data.High.copy()

# %%
hh
# Out:
# 2008-01-01    1.47502
# 2008-01-02    1.47812
# 2008-01-03    1.48254
# 2008-01-05    1.47559
# 2008-01-06    1.47560
#                ...
# 2020-12-23    1.22158
# 2020-12-27    1.22504
# 2020-12-28    1.22752
# 2020-12-29    1.23102
# 2020-12-30    1.23094
# Name: High, Length: 3811, dtype: float64

# %%
# 70 -> fing the local high of the last 70 days
order = 70 # approx. 3 month

# %%
# Run the function, finding the local max's
local_max = argrelextrema(
    hh.values, # the high price dataFrame (in np format) 
    np.greater_equal, # bool operator (>=) 
    order = order # find local high of the last `order` (e.g 70) data points
)

# %%
# For the High price data frame, this is the Indexes of 
# local max for each 70 days:
local_max
# Out:
# (array([  96,  172,  315,  629,  965, 1143, 1430, 1624, 1747, 2084, 2419,
#         2599, 2950, 3065, 3221, 3598, 3809], dtype=int64),)

# %%
# this is the dates of local max:  
data.index[local_max]
# Out:
# DatetimeIndex(['2008-04-21', '2008-07-14', '2008-12-17', '2009-11-24',
#                '2010-11-03', '2011-05-03', '2012-02-23', '2012-09-16',
#                '2013-01-31', '2014-05-07', '2015-08-23', '2016-05-02',
#                '2017-09-07', '2018-02-15', '2018-09-23', '2020-03-08',
#                '2020-12-29'],
#               dtype='datetime64[ns]', freq=None)

# %%
# this is the values of local max:
data.High.values[local_max]
# Out:
# array([1.60194, 1.60388, 1.47204, 1.5144 , 1.42822, 1.49402, 1.34865,
#        1.3172 , 1.3711 , 1.39936, 1.17142, 1.16164, 1.20928, 1.2556 ,
#        1.18151, 1.14963, 1.23102])

# %%
# Plot the local max and the close price: 
 
data.Close.plot(figsize = (20, 8))
plt.vlines(x = data.index[local_max], ymin = data.Low.min(), ymax = data.High.max(), color = "g")
plt.show()

# we can see that its pretty accurate, and we can developing trading strategy
# based on that!
# e.g: where local maximum: short trigger

# %% [markdown]
# ---

# %% [markdown]
# # Identifying Local Lows
#
# > Similar to identify local high, we can identify local low. It can be trigger to BUY (long)

# %%
data
# Out:
#                Open     High      Low    Close
# 2008-01-01  1.45905  1.47502  1.45885  1.47146
# 2008-01-02  1.47146  1.47812  1.46876  1.47510
# 2008-01-03  1.47504  1.48254  1.46958  1.47429
# 2008-01-05  1.47451  1.47559  1.47430  1.47465
# 2008-01-06  1.47465  1.47560  1.46586  1.46954
# ...             ...      ...      ...      ...
# 2020-12-23  1.21873  1.22158  1.21774  1.21849
# 2020-12-27  1.21892  1.22504  1.21812  1.22152
# 2020-12-28  1.22145  1.22752  1.22086  1.22502
# 2020-12-29  1.22508  1.23102  1.22495  1.23000
# 2020-12-30  1.22979  1.23094  1.22094  1.22156
#
# [3811 rows x 4 columns]

# %%
# save the low price 
ll = data.Low.copy()

# %%
# order, is the number of data points that I want to compare the local min
order
# Out:
# 70

# %%
# Finding the local mins in the 
local_min = argrelextrema(ll.values, np.less_equal, order = order)

# %%
# the indexes where the local min
local_min
# Out:
# (array([  17,  268,  385,  818, 1028, 1391, 1575, 1799, 2303, 2493, 2637,
#         2772, 2994, 3256, 3486, 3608, 3770], dtype=int64),)

# %%
# the dates where the local min
data.index[local_min]
# Out:
# DatetimeIndex(['2008-01-21', '2008-10-27', '2009-03-03', '2010-06-06',
#                '2011-01-08', '2012-01-12', '2012-07-23', '2013-04-03',
#                '2015-03-12', '2015-12-02', '2016-06-23', '2017-01-02',
#                '2017-11-06', '2018-11-11', '2019-09-30', '2020-03-22',
#                '2020-11-03'],
#               dtype='datetime64[ns]', freq=None)

# %%
# the values where the local min
data.Low.values[local_min]
# Out:
# array([1.43664, 1.23298, 1.24562, 1.18765, 1.28607, 1.26242, 1.20424,
#        1.27453, 1.04624, 1.05237, 1.09117, 1.03406, 1.15539, 1.12155,
#        1.08792, 1.0636 , 1.16027])

# %% [markdown]
# __Plot the local min and the local max with order of 70__
# - its mean that for each 70 data points we found the local max and the local min.
#
# it can be trading strategy!
#
# but.. can we simply use the code here to create and backtest trading strategies?
#
# __the clear answer is no..__
#
# Why? __look ahead bias.__
# - Where the algorithem find local min/max, it compare the 70 day in past, and __70 days in future (this is the look-ahead bias)__
#
#
# But...
# > We can just look at the 70 days on __the past__, and determine the local min/max in that dates, and plan the future as well...

# %%
data.Close.plot(figsize = (20, 8))
plt.vlines(x = data.index[local_max], ymin = data.Low.min(), ymax = data.High.max(), color = "g", label = "Local Highs")
plt.vlines(x = data.index[local_min], ymin = data.Low.min(), ymax = data.High.max(), color = "r", label = "Local Lows")
plt.title("Local Highs and Lows for Fibonacci Retracement", fontsize = 15)
plt.legend(fontsize = 13)
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# # High and Lows - an iterative approach

# %%
data
# Out:
#                Open     High      Low    Close
# 2008-01-01  1.45905  1.47502  1.45885  1.47146
# 2008-01-02  1.47146  1.47812  1.46876  1.47510
# 2008-01-03  1.47504  1.48254  1.46958  1.47429
# 2008-01-05  1.47451  1.47559  1.47430  1.47465
# 2008-01-06  1.47465  1.47560  1.46586  1.46954
# ...             ...      ...      ...      ...
# 2020-12-23  1.21873  1.22158  1.21774  1.21849
# 2020-12-27  1.21892  1.22504  1.21812  1.22152
# 2020-12-28  1.22145  1.22752  1.22086  1.22502
# 2020-12-29  1.22508  1.23102  1.22495  1.23000
# 2020-12-30  1.22979  1.23094  1.22094  1.22156
#
# [3811 rows x 4 columns]

# %%
order
# Out:
# 70

# %% [markdown]
# __Highs__
# - Initial two columns:
#     - `hh` for store the local high from range of given dates
#     - `hh_date` for store the date on  the hh

# %%
data["hh"] = np.nan
data["hh_date"] = np.nan

# %%
data
# Out:
#                Open     High      Low    Close  hh  hh_date
# 2008-01-01  1.45905  1.47502  1.45885  1.47146 NaN      NaN
# 2008-01-02  1.47146  1.47812  1.46876  1.47510 NaN      NaN
# 2008-01-03  1.47504  1.48254  1.46958  1.47429 NaN      NaN
# 2008-01-05  1.47451  1.47559  1.47430  1.47465 NaN      NaN
# 2008-01-06  1.47465  1.47560  1.46586  1.46954 NaN      NaN
# ...             ...      ...      ...      ...  ..      ...
# 2020-12-23  1.21873  1.22158  1.21774  1.21849 NaN      NaN
# 2020-12-27  1.21892  1.22504  1.21812  1.22152 NaN      NaN
# 2020-12-28  1.22145  1.22752  1.22086  1.22502 NaN      NaN
# 2020-12-29  1.22508  1.23102  1.22495  1.23000 NaN      NaN
# 2020-12-30  1.22979  1.23094  1.22094  1.22156 NaN      NaN
#
# [3811 rows x 6 columns]

# %%
# The iterative approch: find the local max of 'n' last day
# its without look ahead bias (its good.)


for bar in range(len(data)): # iterating over the bars
    
    date = data.index[bar] # determine the current bar´s date
    
    hh = data.iloc[:bar+1].High # get the High column until current bar
    
    # determine all local highs until current bar
    local_max = argrelextrema(hh.values, np.greater_equal, order = order) 
    
    # determine the most recent local high (price) and add to "hh" column
    data.loc[date, "hh"] = data.High.values[local_max][-1] 
    
    # determine the most recent local high (date) and add to "hh_date" column
    data.loc[date, "hh_date"] = data.index[local_max][-1]  


# Its like to find the "rolling local max"
# Out:
# C:\Users\97250\AppData\Local\Temp\ipykernel_6220\1508486204.py:18: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '2008-01-01 00:00:00' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   data.loc[date, "hh_date"] = data.index[local_max][-1]

# %%
data
# Out:
#                Open     High      Low    Close       hh              hh_date
# 2008-01-01  1.45905  1.47502  1.45885  1.47146  1.47502  2008-01-01 00:00:00
# 2008-01-02  1.47146  1.47812  1.46876  1.47510  1.47812  2008-01-02 00:00:00
# 2008-01-03  1.47504  1.48254  1.46958  1.47429  1.48254  2008-01-03 00:00:00
# 2008-01-05  1.47451  1.47559  1.47430  1.47465  1.48254  2008-01-03 00:00:00
# 2008-01-06  1.47465  1.47560  1.46586  1.46954  1.48254  2008-01-03 00:00:00
# ...             ...      ...      ...      ...      ...                  ...
# 2020-12-23  1.21873  1.22158  1.21774  1.21849  1.22728  2020-12-16 00:00:00
# 2020-12-27  1.21892  1.22504  1.21812  1.22152  1.22728  2020-12-16 00:00:00
# 2020-12-28  1.22145  1.22752  1.22086  1.22502  1.22752  2020-12-28 00:00:00
# 2020-12-29  1.22508  1.23102  1.22495  1.23000  1.23102  2020-12-29 00:00:00
# 2020-12-30  1.22979  1.23094  1.22094  1.22156  1.23102  2020-12-29 00:00:00
#
# [3811 rows x 6 columns]

# %% [markdown]
# __Lows__

# %%
data["ll"] = np.nan
data["ll_date"] = np.nan

# %%
# Find the local min, the interative approch

for bar in range(len(data)): # iterating over the bars
    date = data.index[bar] # determine the current bar´s date
    ll = data.iloc[:bar+1].Low # get the high column until current bar
    
    # determine all local lows until current bar
    local_min = argrelextrema(ll.values, np.less_equal, order = order)
    
    # determine the most recent local low (price) and add to "ll" column
    data.loc[date, "ll"] = data.Low.values[local_min][-1]
    
    # determine the most recent local low (date) and add to "ll_date" column
    data.loc[date, "ll_date"] = data.index[local_min][-1]


# Its like to find the "rolling local min"
# Out:
# C:\Users\97250\AppData\Local\Temp\ipykernel_6220\3755139481.py:14: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '2008-01-01 00:00:00' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   data.loc[date, "ll_date"] = data.index[local_min][-1]

# %%
data
# Out:
#                Open     High      Low    Close       hh              hh_date  \
# 2008-01-01  1.45905  1.47502  1.45885  1.47146  1.47502  2008-01-01 00:00:00
# 2008-01-02  1.47146  1.47812  1.46876  1.47510  1.47812  2008-01-02 00:00:00
# 2008-01-03  1.47504  1.48254  1.46958  1.47429  1.48254  2008-01-03 00:00:00
# 2008-01-05  1.47451  1.47559  1.47430  1.47465  1.48254  2008-01-03 00:00:00
# 2008-01-06  1.47465  1.47560  1.46586  1.46954  1.48254  2008-01-03 00:00:00
# ...             ...      ...      ...      ...      ...                  ...
# 2020-12-23  1.21873  1.22158  1.21774  1.21849  1.22728  2020-12-16 00:00:00
# 2020-12-27  1.21892  1.22504  1.21812  1.22152  1.22728  2020-12-16 00:00:00
# 2020-12-28  1.22145  1.22752  1.22086  1.22502  1.22752  2020-12-28 00:00:00
# 2020-12-29  1.22508  1.23102  1.22495  1.23000  1.23102  2020-12-29 00:00:00
# 2020-12-30  1.22979  1.23094  1.22094  1.22156  1.23102  2020-12-29 00:00:00
#
#                  ll              ll_date
# 2008-01-01  1.45885  2008-01-01 00:00:00
# 2008-01-02  1.45885  2008-01-01 00:00:00
# 2008-01-03  1.45885  2008-01-01 00:00:00
# 2008-01-05  1.45885  2008-01-01 00:00:00
# 2008-01-06  1.45885  2008-01-01 00:00:00
# ...             ...                  ...
# 2020-12-23  1.16027  2020-11-03 00:00:00
# 2020-12-27  1.16027  2020-11-03 00:00:00
# 2020-12-28  1.16027  2020-11-03 00:00:00
# 2020-12-29  1.16027  2020-11-03 00:00:00
# 2020-12-30  1.16027  2020-11-03 00:00:00
#
# [3811 rows x 8 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3811 entries, 2008-01-01 to 2020-12-30
# Data columns (total 8 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Open     3811 non-null   float64
#  1   High     3811 non-null   float64
#  2   Low      3811 non-null   float64
#  3   Close    3811 non-null   float64
#  4   hh       3811 non-null   float64
#  5   hh_date  3811 non-null   object
#  6   ll       3811 non-null   float64
#  7   ll_date  3811 non-null   object
# dtypes: float64(6), object(2)
# memory usage: 397.0+ KB

# %% [markdown]
# ---

# %% [markdown]
# # Identifying Trends (Uptrend / Downtrend)

# %% [markdown]
# __Lets plot the Close price, rolling local high/low:__
#
# - In green: we have the rolling local max
# - In red: we have the rolling local min

# %%
data.loc["2010":"2011", ["Close", "hh", "ll"]].plot(figsize = (12, 8), title = "EUR/USD",
                                                    fontsize = 12)
plt.legend(fontsize = 12)
plt.show()


# Interpretation and strategy for trading:
# - if you see that the local min updating more frequency than the local max,
#   it can be a signal to SELL.
#   for ilustration, you can see that at the start, the local min updated
#   more frequency, while the local max stay constrant over long time.
#   its signal to sell! 
# 
# - And of curse, the vica verca:
#   if local max update more frequency while the local min stay constant,
#   it can be signal to BUY

# %% [markdown]
# __Downtrend__: Most recent lower low is more recent than the most recent higher high <br>
# __Uptrend__: Most recent higher high is more recent than the most recent lower low

# %%
# defint positions:
# if the *date* of local max higher from the *date* of local min,
# its mean that the local max update frequency, and its signal to BUY (1)
# otherwise, signal to SELL (-1)
data["Trend"] = np.where(data.hh_date > data.ll_date, 1, -1)

# %%
data
# Out:
#                Open     High      Low    Close       hh              hh_date  \
# 2008-01-01  1.45905  1.47502  1.45885  1.47146  1.47502  2008-01-01 00:00:00
# 2008-01-02  1.47146  1.47812  1.46876  1.47510  1.47812  2008-01-02 00:00:00
# 2008-01-03  1.47504  1.48254  1.46958  1.47429  1.48254  2008-01-03 00:00:00
# 2008-01-05  1.47451  1.47559  1.47430  1.47465  1.48254  2008-01-03 00:00:00
# 2008-01-06  1.47465  1.47560  1.46586  1.46954  1.48254  2008-01-03 00:00:00
# ...             ...      ...      ...      ...      ...                  ...
# 2020-12-23  1.21873  1.22158  1.21774  1.21849  1.22728  2020-12-16 00:00:00
# 2020-12-27  1.21892  1.22504  1.21812  1.22152  1.22728  2020-12-16 00:00:00
# 2020-12-28  1.22145  1.22752  1.22086  1.22502  1.22752  2020-12-28 00:00:00
# 2020-12-29  1.22508  1.23102  1.22495  1.23000  1.23102  2020-12-29 00:00:00
# 2020-12-30  1.22979  1.23094  1.22094  1.22156  1.23102  2020-12-29 00:00:00
#
#                  ll              ll_date  Trend
# 2008-01-01  1.45885  2008-01-01 00:00:00     -1
# 2008-01-02  1.45885  2008-01-01 00:00:00      1
# 2008-01-03  1.45885  2008-01-01 00:00:00      1
# 2008-01-05  1.45885  2008-01-01 00:00:00      1
# 2008-01-06  1.45885  2008-01-01 00:00:00      1
# ...             ...                  ...    ...
# 2020-12-23  1.16027  2020-11-03 00:00:00      1
# 2020-12-27  1.16027  2020-11-03 00:00:00      1
# 2020-12-28  1.16027  2020-11-03 00:00:00      1
# 2020-12-29  1.16027  2020-11-03 00:00:00      1
# 2020-12-30  1.16027  2020-11-03 00:00:00      1
#
# [3811 rows x 9 columns]

# %% [markdown]
# __Plot the `Close price`, `rolling local max/min`, and the strategy positions__

# %%
data.loc["2010":"2011", ["Close", "hh", "ll", "Trend"]].plot(figsize = (12, 8), title = "EUR/USD",
                                                             fontsize = 12, secondary_y = "Trend")
plt.legend(fontsize = 12)
plt.show()

# %%
data["Trend"] = np.where(data.hh_date > data.ll_date, "Up", "Down")

# %%
data
# Out:
#                Open     High      Low    Close       hh              hh_date  \
# 2008-01-01  1.45905  1.47502  1.45885  1.47146  1.47502  2008-01-01 00:00:00
# 2008-01-02  1.47146  1.47812  1.46876  1.47510  1.47812  2008-01-02 00:00:00
# 2008-01-03  1.47504  1.48254  1.46958  1.47429  1.48254  2008-01-03 00:00:00
# 2008-01-05  1.47451  1.47559  1.47430  1.47465  1.48254  2008-01-03 00:00:00
# 2008-01-06  1.47465  1.47560  1.46586  1.46954  1.48254  2008-01-03 00:00:00
# ...             ...      ...      ...      ...      ...                  ...
# 2020-12-23  1.21873  1.22158  1.21774  1.21849  1.22728  2020-12-16 00:00:00
# 2020-12-27  1.21892  1.22504  1.21812  1.22152  1.22728  2020-12-16 00:00:00
# 2020-12-28  1.22145  1.22752  1.22086  1.22502  1.22752  2020-12-28 00:00:00
# 2020-12-29  1.22508  1.23102  1.22495  1.23000  1.23102  2020-12-29 00:00:00
# 2020-12-30  1.22979  1.23094  1.22094  1.22156  1.23102  2020-12-29 00:00:00
#
#                  ll              ll_date Trend
# 2008-01-01  1.45885  2008-01-01 00:00:00  Down
# 2008-01-02  1.45885  2008-01-01 00:00:00    Up
# 2008-01-03  1.45885  2008-01-01 00:00:00    Up
# 2008-01-05  1.45885  2008-01-01 00:00:00    Up
# 2008-01-06  1.45885  2008-01-01 00:00:00    Up
# ...             ...                  ...   ...
# 2020-12-23  1.16027  2020-11-03 00:00:00    Up
# 2020-12-27  1.16027  2020-11-03 00:00:00    Up
# 2020-12-28  1.16027  2020-11-03 00:00:00    Up
# 2020-12-29  1.16027  2020-11-03 00:00:00    Up
# 2020-12-30  1.16027  2020-11-03 00:00:00    Up
#
# [3811 rows x 9 columns]

# %%
data.drop(columns = ["hh_date", "ll_date"], inplace = True)

# %%
data
# Out:
#                Open     High      Low    Close       hh       ll Trend
# 2008-01-01  1.45905  1.47502  1.45885  1.47146  1.47502  1.45885  Down
# 2008-01-02  1.47146  1.47812  1.46876  1.47510  1.47812  1.45885    Up
# 2008-01-03  1.47504  1.48254  1.46958  1.47429  1.48254  1.45885    Up
# 2008-01-05  1.47451  1.47559  1.47430  1.47465  1.48254  1.45885    Up
# 2008-01-06  1.47465  1.47560  1.46586  1.46954  1.48254  1.45885    Up
# ...             ...      ...      ...      ...      ...      ...   ...
# 2020-12-23  1.21873  1.22158  1.21774  1.21849  1.22728  1.16027    Up
# 2020-12-27  1.21892  1.22504  1.21812  1.22152  1.22728  1.16027    Up
# 2020-12-28  1.22145  1.22752  1.22086  1.22502  1.22752  1.16027    Up
# 2020-12-29  1.22508  1.23102  1.22495  1.23000  1.23102  1.16027    Up
# 2020-12-30  1.22979  1.23094  1.22094  1.22156  1.23102  1.16027    Up
#
# [3811 rows x 7 columns]

# %%
data.Trend.value_counts()
# Out:
# Trend
# Down    2032
# Up      1779
# Name: count, dtype: int64

# %% [markdown]
# ---

# %% [markdown]
# # Adding Fibonacci Retracement Levels

# %%
data
# Out:
#                Open     High      Low    Close       hh       ll Trend
# 2008-01-01  1.45905  1.47502  1.45885  1.47146  1.47502  1.45885  Down
# 2008-01-02  1.47146  1.47812  1.46876  1.47510  1.47812  1.45885    Up
# 2008-01-03  1.47504  1.48254  1.46958  1.47429  1.48254  1.45885    Up
# 2008-01-05  1.47451  1.47559  1.47430  1.47465  1.48254  1.45885    Up
# 2008-01-06  1.47465  1.47560  1.46586  1.46954  1.48254  1.45885    Up
# ...             ...      ...      ...      ...      ...      ...   ...
# 2020-12-23  1.21873  1.22158  1.21774  1.21849  1.22728  1.16027    Up
# 2020-12-27  1.21892  1.22504  1.21812  1.22152  1.22728  1.16027    Up
# 2020-12-28  1.22145  1.22752  1.22086  1.22502  1.22752  1.16027    Up
# 2020-12-29  1.22508  1.23102  1.22495  1.23000  1.23102  1.16027    Up
# 2020-12-30  1.22979  1.23094  1.22094  1.22156  1.23102  1.16027    Up
#
# [3811 rows x 7 columns]

# %% [markdown]
# __Fibonacci Levels derived from Fibonacci numbers: 23.6%, 38.2%, (61.8%)__

# %%
# Add the Fibonacci 23.6% 
data["R23.6"] = np.where(data.Trend == "Up", # If the trend is up (local max update more frequency) 
                         data.hh - (data.hh-data.ll) * 0.236, # put suppurt line on 23.6% below
                         data.hh - (data.hh-data.ll) * (1-0.236)) # else, if trend is down, put resistance line in 1 - 0.236 = 76.4%

# %%
data
# Out:
#                Open     High      Low    Close       hh       ll Trend  \
# 2008-01-01  1.45905  1.47502  1.45885  1.47146  1.47502  1.45885  Down
# 2008-01-02  1.47146  1.47812  1.46876  1.47510  1.47812  1.45885    Up
# 2008-01-03  1.47504  1.48254  1.46958  1.47429  1.48254  1.45885    Up
# 2008-01-05  1.47451  1.47559  1.47430  1.47465  1.48254  1.45885    Up
# 2008-01-06  1.47465  1.47560  1.46586  1.46954  1.48254  1.45885    Up
# ...             ...      ...      ...      ...      ...      ...   ...
# 2020-12-23  1.21873  1.22158  1.21774  1.21849  1.22728  1.16027    Up
# 2020-12-27  1.21892  1.22504  1.21812  1.22152  1.22728  1.16027    Up
# 2020-12-28  1.22145  1.22752  1.22086  1.22502  1.22752  1.16027    Up
# 2020-12-29  1.22508  1.23102  1.22495  1.23000  1.23102  1.16027    Up
# 2020-12-30  1.22979  1.23094  1.22094  1.22156  1.23102  1.16027    Up
#
#                R23.6
# 2008-01-01  1.462666
# 2008-01-02  1.473572
# 2008-01-03  1.476949
# 2008-01-05  1.476949
# 2008-01-06  1.476949
# ...              ...
# 2020-12-23  1.211466
# 2020-12-27  1.211466
# 2020-12-28  1.211649
# 2020-12-29  1.214323
# 2020-12-30  1.214323
#
# [3811 rows x 8 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3811 entries, 2008-01-01 to 2020-12-30
# Data columns (total 8 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    3811 non-null   float64
#  1   High    3811 non-null   float64
#  2   Low     3811 non-null   float64
#  3   Close   3811 non-null   float64
#  4   hh      3811 non-null   float64
#  5   ll      3811 non-null   float64
#  6   Trend   3811 non-null   object
#  7   R23.6   3811 non-null   float64
# dtypes: float64(7), object(1)
# memory usage: 397.0+ KB

# %%
# And also for 38.2 level 
data["R38.2"] = np.where(data.Trend == "Up", 
                         data.hh - (data.hh-data.ll) * 0.382, 
                         data.hh - (data.hh-data.ll) * (1-0.382))

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3811 entries, 2008-01-01 to 2020-12-30
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    3811 non-null   float64
#  1   High    3811 non-null   float64
#  2   Low     3811 non-null   float64
#  3   Close   3811 non-null   float64
#  4   hh      3811 non-null   float64
#  5   ll      3811 non-null   float64
#  6   Trend   3811 non-null   object
#  7   R23.6   3811 non-null   float64
#  8   R38.2   3811 non-null   float64
# dtypes: float64(8), object(1)
# memory usage: 426.8+ KB

# %%
data
# Out:
#                Open     High      Low    Close       hh       ll Trend  \
# 2008-01-01  1.45905  1.47502  1.45885  1.47146  1.47502  1.45885  Down
# 2008-01-02  1.47146  1.47812  1.46876  1.47510  1.47812  1.45885    Up
# 2008-01-03  1.47504  1.48254  1.46958  1.47429  1.48254  1.45885    Up
# 2008-01-05  1.47451  1.47559  1.47430  1.47465  1.48254  1.45885    Up
# 2008-01-06  1.47465  1.47560  1.46586  1.46954  1.48254  1.45885    Up
# ...             ...      ...      ...      ...      ...      ...   ...
# 2020-12-23  1.21873  1.22158  1.21774  1.21849  1.22728  1.16027    Up
# 2020-12-27  1.21892  1.22504  1.21812  1.22152  1.22728  1.16027    Up
# 2020-12-28  1.22145  1.22752  1.22086  1.22502  1.22752  1.16027    Up
# 2020-12-29  1.22508  1.23102  1.22495  1.23000  1.23102  1.16027    Up
# 2020-12-30  1.22979  1.23094  1.22094  1.22156  1.23102  1.16027    Up
#
#                R23.6     R38.2
# 2008-01-01  1.462666  1.465027
# 2008-01-02  1.473572  1.470759
# 2008-01-03  1.476949  1.473490
# 2008-01-05  1.476949  1.473490
# 2008-01-06  1.476949  1.473490
# ...              ...       ...
# 2020-12-23  1.211466  1.201682
# 2020-12-27  1.211466  1.201682
# 2020-12-28  1.211649  1.201831
# 2020-12-29  1.214323  1.203993
# 2020-12-30  1.214323  1.203993
#
# [3811 rows x 9 columns]

# %% [markdown]
# ---

# %% [markdown]
# # A Fibonacci Retracement (23.6%) Breakout Strategy

# %%
data
# Out:
#                Open     High      Low    Close       hh       ll Trend  \
# 2008-01-01  1.45905  1.47502  1.45885  1.47146  1.47502  1.45885  Down
# 2008-01-02  1.47146  1.47812  1.46876  1.47510  1.47812  1.45885    Up
# 2008-01-03  1.47504  1.48254  1.46958  1.47429  1.48254  1.45885    Up
# 2008-01-05  1.47451  1.47559  1.47430  1.47465  1.48254  1.45885    Up
# 2008-01-06  1.47465  1.47560  1.46586  1.46954  1.48254  1.45885    Up
# ...             ...      ...      ...      ...      ...      ...   ...
# 2020-12-23  1.21873  1.22158  1.21774  1.21849  1.22728  1.16027    Up
# 2020-12-27  1.21892  1.22504  1.21812  1.22152  1.22728  1.16027    Up
# 2020-12-28  1.22145  1.22752  1.22086  1.22502  1.22752  1.16027    Up
# 2020-12-29  1.22508  1.23102  1.22495  1.23000  1.23102  1.16027    Up
# 2020-12-30  1.22979  1.23094  1.22094  1.22156  1.23102  1.16027    Up
#
#                R23.6     R38.2
# 2008-01-01  1.462666  1.465027
# 2008-01-02  1.473572  1.470759
# 2008-01-03  1.476949  1.473490
# 2008-01-05  1.476949  1.473490
# 2008-01-06  1.476949  1.473490
# ...              ...       ...
# 2020-12-23  1.211466  1.201682
# 2020-12-27  1.211466  1.201682
# 2020-12-28  1.211649  1.201831
# 2020-12-29  1.214323  1.203993
# 2020-12-30  1.214323  1.203993
#
# [3811 rows x 9 columns]

# %% [markdown]
# __Go Neutral when reaching new Highs/lows (e.g. when Trend reverses)__

# %%
data["position"] = np.where(  
    # if the most recent high/low changed, its signal to go neutral
    (data.hh != data.hh.shift()) | (data.ll != data.ll.shift()), 
    0, 
    np.nan
)

# %%
data.position.value_counts()
# Out:
# position
# 0.0    501
# Name: count, dtype: int64

# %% [markdown]
# ### Downtrend Decisions (opportunities to take long)

# %% [markdown]
# > __Go Long when Price breaks R23.6__

# %%
data["position"] = np.where(
    # if the trand is Down
    (data.Trend == "Down") &  
    # and the previos close small then 23.6%
    (data.Close.shift() < data["R23.6"].shift()) & 
    # and then the current close brake cross the 23.6%
    (data.Close > data["R23.6"]), 
    1, # its signal to LONG! the price came from down, 
       # and brake the rescident of the 23.6%!  
    data.position
)

# %% [markdown]
# > __Go Neutral when Price reaches/breaks R38.2__ (Take Profit)

# %%
# if the price cross the 38.2%, its time to take profit! 
# e.g, the price came up from R23.6 to R38.2
data["position"] = np.where(
    # if the trand is down
    (data.Trend == "Down") &
    # and the previos close smaller than the price on the 38.2%  
    (data.Close.shift() < data["R38.2"].shift()) & 
    # and the price now brake up the 38.2% 
    (data.Close >= data["R38.2"]), 
    0, # take profit! its mean that the price probably came from R23.6 to R38.2
    data.position
)

# %% [markdown]
# > __Go Neutral when Prices reaches/breaks R0__ (Stop Loss)

# %%
data["position"] = np.where(
    # If the tread if down
    (data.Trend == "Down") & 
    # and previes close was bigger than the previos low
    (data.Close.shift() > data.ll.shift()) & 
    # and now the Close smaller than low
    (data.Close <= data.ll), 
    0, # its time to stop loss.
    data.position
)

# %%
data.position.value_counts()
# Out:
# position
# 0.0    544
# 1.0     79
# Name: count, dtype: int64

# %% [markdown]
# ### Uptrend Decisions (opportunities to take short)

# %% [markdown]
# __Go Short when Price breaks R23.6__

# %%
data["position"] = np.where(
    (data.Trend == "Up") & 
    (data.Close.shift() > data["R23.6"].shift()) & 
    (data.Close < data["R23.6"]),
    -1, 
    data.position
)

# %%
data.position.value_counts()
# Out:
# position
#  0.0    541
#  1.0     79
# -1.0     75
# Name: count, dtype: int64

# %% [markdown]
# __Go Neutral when Price reaches/breaks R38.2__ (Take profit)

# %%
data["position"] = np.where(
    (data.Trend == "Up") & 
    (data.Close.shift() > data["R38.2"].shift()) & 
    (data.Close <= data["R38.2"]), 
    0, 
    data.position
)

# %% [markdown]
# __Go Neutral when Prices reaches/breaks R0__ (Stop Loss)

# %%
data["position"] = np.where(
    (data.Trend == "Up") & 
    (data.Close.shift() < data.hh.shift()) & 
    (data.Close >= data.hh), 
    0, 
    data.position
)

# %% [markdown]
# __Go Neutral when reaching new Highs/lows (e.g. when Trend reverses)__

# %%
data["position"] = np.where(
    (data.hh != data.hh.shift()) | (data.ll != data.ll.shift()), 
    0, 
    data.position
)

# %%
data["position"] = data.position.ffill()

# %%
data.position.value_counts()
# Out:
# position
#  0.0    2701
#  1.0     605
# -1.0     503
# Name: count, dtype: int64

# %%
data
# Out:
#                Open     High      Low    Close       hh       ll Trend  \
# 2008-01-03  1.47504  1.48254  1.46958  1.47429  1.48254  1.45885    Up
# 2008-01-05  1.47451  1.47559  1.47430  1.47465  1.48254  1.45885    Up
# 2008-01-06  1.47465  1.47560  1.46586  1.46954  1.48254  1.45885    Up
# 2008-01-07  1.46954  1.47444  1.46804  1.47078  1.48254  1.45885    Up
# 2008-01-08  1.47074  1.47426  1.46394  1.46594  1.48254  1.45885    Up
# ...             ...      ...      ...      ...      ...      ...   ...
# 2020-12-23  1.21873  1.22158  1.21774  1.21849  1.22728  1.16027    Up
# 2020-12-27  1.21892  1.22504  1.21812  1.22152  1.22728  1.16027    Up
# 2020-12-28  1.22145  1.22752  1.22086  1.22502  1.22752  1.16027    Up
# 2020-12-29  1.22508  1.23102  1.22495  1.23000  1.23102  1.16027    Up
# 2020-12-30  1.22979  1.23094  1.22094  1.22156  1.23102  1.16027    Up
#
#                R23.6     R38.2  position   returns  strategy  trades  \
# 2008-01-03  1.476949  1.473490       0.0 -0.000549      -0.0     0.0
# 2008-01-05  1.476949  1.473490       0.0  0.000244       0.0     0.0
# 2008-01-06  1.476949  1.473490       0.0 -0.003471      -0.0     0.0
# 2008-01-07  1.476949  1.473490       0.0  0.000843       0.0     0.0
# 2008-01-08  1.476949  1.473490       0.0 -0.003296      -0.0     0.0
# ...              ...       ...       ...       ...       ...     ...
# 2020-12-23  1.211466  1.201682       0.0 -0.000057      -0.0     0.0
# 2020-12-27  1.211466  1.201682       0.0  0.002484       0.0     0.0
# 2020-12-28  1.211649  1.201831       0.0  0.002861       0.0     0.0
# 2020-12-29  1.214323  1.203993       0.0  0.004057       0.0     0.0
# 2020-12-30  1.214323  1.203993       0.0 -0.006885      -0.0     0.0
#
#             strategy_net  creturns  cstrategy  cstrategy_net
# 2008-01-03          -0.0  0.999451   1.000000       1.000000
# 2008-01-05           0.0  0.999695   1.000000       1.000000
# 2008-01-06          -0.0  0.996231   1.000000       1.000000
# 2008-01-07           0.0  0.997071   1.000000       1.000000
# 2008-01-08          -0.0  0.993790   1.000000       1.000000
# ...                  ...       ...        ...            ...
# 2020-12-23          -0.0  0.826039   1.239926       1.225773
# 2020-12-27           0.0  0.828093   1.239926       1.225773
# 2020-12-28           0.0  0.830466   1.239926       1.225773
# 2020-12-29           0.0  0.833842   1.239926       1.225773
# 2020-12-30          -0.0  0.828120   1.239926       1.225773
#
# [3809 rows x 17 columns]

# %%
data.loc[:, ["Close", "position"]].plot(figsize = (12, 8), fontsize = 12, secondary_y = "position")
plt.legend(fontsize = 12)
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# # Vectorized Strategy Backtesting

# %%
data
# Out:
#                Open     High      Low    Close       hh       ll Trend  \
# 2008-01-03  1.47504  1.48254  1.46958  1.47429  1.48254  1.45885    Up
# 2008-01-05  1.47451  1.47559  1.47430  1.47465  1.48254  1.45885    Up
# 2008-01-06  1.47465  1.47560  1.46586  1.46954  1.48254  1.45885    Up
# 2008-01-07  1.46954  1.47444  1.46804  1.47078  1.48254  1.45885    Up
# 2008-01-08  1.47074  1.47426  1.46394  1.46594  1.48254  1.45885    Up
# ...             ...      ...      ...      ...      ...      ...   ...
# 2020-12-23  1.21873  1.22158  1.21774  1.21849  1.22728  1.16027    Up
# 2020-12-27  1.21892  1.22504  1.21812  1.22152  1.22728  1.16027    Up
# 2020-12-28  1.22145  1.22752  1.22086  1.22502  1.22752  1.16027    Up
# 2020-12-29  1.22508  1.23102  1.22495  1.23000  1.23102  1.16027    Up
# 2020-12-30  1.22979  1.23094  1.22094  1.22156  1.23102  1.16027    Up
#
#                R23.6     R38.2  position   returns  strategy  trades  \
# 2008-01-03  1.476949  1.473490       0.0 -0.000549      -0.0     0.0
# 2008-01-05  1.476949  1.473490       0.0  0.000244       0.0     0.0
# 2008-01-06  1.476949  1.473490       0.0 -0.003471      -0.0     0.0
# 2008-01-07  1.476949  1.473490       0.0  0.000843       0.0     0.0
# 2008-01-08  1.476949  1.473490       0.0 -0.003296      -0.0     0.0
# ...              ...       ...       ...       ...       ...     ...
# 2020-12-23  1.211466  1.201682       0.0 -0.000057      -0.0     0.0
# 2020-12-27  1.211466  1.201682       0.0  0.002484       0.0     0.0
# 2020-12-28  1.211649  1.201831       0.0  0.002861       0.0     0.0
# 2020-12-29  1.214323  1.203993       0.0  0.004057       0.0     0.0
# 2020-12-30  1.214323  1.203993       0.0 -0.006885      -0.0     0.0
#
#             strategy_net  creturns  cstrategy  cstrategy_net
# 2008-01-03          -0.0  0.999451   1.000000       1.000000
# 2008-01-05           0.0  0.999695   1.000000       1.000000
# 2008-01-06          -0.0  0.996231   1.000000       1.000000
# 2008-01-07           0.0  0.997071   1.000000       1.000000
# 2008-01-08          -0.0  0.993790   1.000000       1.000000
# ...                  ...       ...        ...            ...
# 2020-12-23          -0.0  0.826039   1.239926       1.225773
# 2020-12-27           0.0  0.828093   1.239926       1.225773
# 2020-12-28           0.0  0.830466   1.239926       1.225773
# 2020-12-29           0.0  0.833842   1.239926       1.225773
# 2020-12-30          -0.0  0.828120   1.239926       1.225773
#
# [3809 rows x 17 columns]

# %%
data["returns"] = np.log(data.Close.div(data.Close.shift(1)))

# %%
data.dropna(inplace = True)

# %%
data
# Out:
#                Open     High      Low    Close       hh       ll Trend  \
# 2008-01-05  1.47451  1.47559  1.47430  1.47465  1.48254  1.45885    Up
# 2008-01-06  1.47465  1.47560  1.46586  1.46954  1.48254  1.45885    Up
# 2008-01-07  1.46954  1.47444  1.46804  1.47078  1.48254  1.45885    Up
# 2008-01-08  1.47074  1.47426  1.46394  1.46594  1.48254  1.45885    Up
# 2008-01-09  1.46598  1.48134  1.46418  1.48038  1.48254  1.45885    Up
# ...             ...      ...      ...      ...      ...      ...   ...
# 2020-12-23  1.21873  1.22158  1.21774  1.21849  1.22728  1.16027    Up
# 2020-12-27  1.21892  1.22504  1.21812  1.22152  1.22728  1.16027    Up
# 2020-12-28  1.22145  1.22752  1.22086  1.22502  1.22752  1.16027    Up
# 2020-12-29  1.22508  1.23102  1.22495  1.23000  1.23102  1.16027    Up
# 2020-12-30  1.22979  1.23094  1.22094  1.22156  1.23102  1.16027    Up
#
#                R23.6     R38.2  position   returns  strategy  trades  \
# 2008-01-05  1.476949  1.473490       0.0  0.000244       0.0     0.0
# 2008-01-06  1.476949  1.473490       0.0 -0.003471      -0.0     0.0
# 2008-01-07  1.476949  1.473490       0.0  0.000843       0.0     0.0
# 2008-01-08  1.476949  1.473490       0.0 -0.003296      -0.0     0.0
# 2008-01-09  1.476949  1.473490       0.0  0.009802       0.0     0.0
# ...              ...       ...       ...       ...       ...     ...
# 2020-12-23  1.211466  1.201682       0.0 -0.000057      -0.0     0.0
# 2020-12-27  1.211466  1.201682       0.0  0.002484       0.0     0.0
# 2020-12-28  1.211649  1.201831       0.0  0.002861       0.0     0.0
# 2020-12-29  1.214323  1.203993       0.0  0.004057       0.0     0.0
# 2020-12-30  1.214323  1.203993       0.0 -0.006885      -0.0     0.0
#
#             strategy_net  creturns  cstrategy  cstrategy_net
# 2008-01-05           0.0  0.999695   1.000000       1.000000
# 2008-01-06          -0.0  0.996231   1.000000       1.000000
# 2008-01-07           0.0  0.997071   1.000000       1.000000
# 2008-01-08          -0.0  0.993790   1.000000       1.000000
# 2008-01-09           0.0  1.003579   1.000000       1.000000
# ...                  ...       ...        ...            ...
# 2020-12-23          -0.0  0.826039   1.239926       1.225773
# 2020-12-27           0.0  0.828093   1.239926       1.225773
# 2020-12-28           0.0  0.830466   1.239926       1.225773
# 2020-12-29           0.0  0.833842   1.239926       1.225773
# 2020-12-30          -0.0  0.828120   1.239926       1.225773
#
# [3808 rows x 17 columns]

# %%
data["strategy"] = data.position.shift(1) * data["returns"]

# %%
data
# Out:
#                Open     High      Low    Close       hh       ll Trend  \
# 2008-01-05  1.47451  1.47559  1.47430  1.47465  1.48254  1.45885    Up
# 2008-01-06  1.47465  1.47560  1.46586  1.46954  1.48254  1.45885    Up
# 2008-01-07  1.46954  1.47444  1.46804  1.47078  1.48254  1.45885    Up
# 2008-01-08  1.47074  1.47426  1.46394  1.46594  1.48254  1.45885    Up
# 2008-01-09  1.46598  1.48134  1.46418  1.48038  1.48254  1.45885    Up
# ...             ...      ...      ...      ...      ...      ...   ...
# 2020-12-23  1.21873  1.22158  1.21774  1.21849  1.22728  1.16027    Up
# 2020-12-27  1.21892  1.22504  1.21812  1.22152  1.22728  1.16027    Up
# 2020-12-28  1.22145  1.22752  1.22086  1.22502  1.22752  1.16027    Up
# 2020-12-29  1.22508  1.23102  1.22495  1.23000  1.23102  1.16027    Up
# 2020-12-30  1.22979  1.23094  1.22094  1.22156  1.23102  1.16027    Up
#
#                R23.6     R38.2  position   returns  strategy  trades  \
# 2008-01-05  1.476949  1.473490       0.0  0.000244       NaN     0.0
# 2008-01-06  1.476949  1.473490       0.0 -0.003471      -0.0     0.0
# 2008-01-07  1.476949  1.473490       0.0  0.000843       0.0     0.0
# 2008-01-08  1.476949  1.473490       0.0 -0.003296      -0.0     0.0
# 2008-01-09  1.476949  1.473490       0.0  0.009802       0.0     0.0
# ...              ...       ...       ...       ...       ...     ...
# 2020-12-23  1.211466  1.201682       0.0 -0.000057      -0.0     0.0
# 2020-12-27  1.211466  1.201682       0.0  0.002484       0.0     0.0
# 2020-12-28  1.211649  1.201831       0.0  0.002861       0.0     0.0
# 2020-12-29  1.214323  1.203993       0.0  0.004057       0.0     0.0
# 2020-12-30  1.214323  1.203993       0.0 -0.006885      -0.0     0.0
#
#             strategy_net  creturns  cstrategy  cstrategy_net
# 2008-01-05           0.0  0.999695   1.000000       1.000000
# 2008-01-06          -0.0  0.996231   1.000000       1.000000
# 2008-01-07           0.0  0.997071   1.000000       1.000000
# 2008-01-08          -0.0  0.993790   1.000000       1.000000
# 2008-01-09           0.0  1.003579   1.000000       1.000000
# ...                  ...       ...        ...            ...
# 2020-12-23          -0.0  0.826039   1.239926       1.225773
# 2020-12-27           0.0  0.828093   1.239926       1.225773
# 2020-12-28           0.0  0.830466   1.239926       1.225773
# 2020-12-29           0.0  0.833842   1.239926       1.225773
# 2020-12-30          -0.0  0.828120   1.239926       1.225773
#
# [3808 rows x 17 columns]

# %%
data.dropna(inplace = True)

# %%
ptc = 0.00007

# %%
data["trades"] = data.position.diff().fillna(0).abs()

# %%
data.trades.value_counts()
# Out:
# trades
# 0.0    3643
# 1.0     164
# Name: count, dtype: int64

# %%
data["strategy_net"] = data.strategy - data.trades * ptc

# %%
data["creturns"] = data["returns"].cumsum().apply(np.exp)
data["cstrategy"] = data["strategy"].cumsum().apply(np.exp)
data["cstrategy_net"] = data["strategy_net"].cumsum().apply(np.exp)

# %%
data
# Out:
#                Open     High      Low    Close       hh       ll Trend  \
# 2008-01-06  1.47465  1.47560  1.46586  1.46954  1.48254  1.45885    Up
# 2008-01-07  1.46954  1.47444  1.46804  1.47078  1.48254  1.45885    Up
# 2008-01-08  1.47074  1.47426  1.46394  1.46594  1.48254  1.45885    Up
# 2008-01-09  1.46598  1.48134  1.46418  1.48038  1.48254  1.45885    Up
# 2008-01-10  1.48030  1.48194  1.47618  1.47767  1.48254  1.45885    Up
# ...             ...      ...      ...      ...      ...      ...   ...
# 2020-12-23  1.21873  1.22158  1.21774  1.21849  1.22728  1.16027    Up
# 2020-12-27  1.21892  1.22504  1.21812  1.22152  1.22728  1.16027    Up
# 2020-12-28  1.22145  1.22752  1.22086  1.22502  1.22752  1.16027    Up
# 2020-12-29  1.22508  1.23102  1.22495  1.23000  1.23102  1.16027    Up
# 2020-12-30  1.22979  1.23094  1.22094  1.22156  1.23102  1.16027    Up
#
#                R23.6     R38.2  position   returns  strategy  trades  \
# 2008-01-06  1.476949  1.473490       0.0 -0.003471      -0.0     0.0
# 2008-01-07  1.476949  1.473490       0.0  0.000843       0.0     0.0
# 2008-01-08  1.476949  1.473490       0.0 -0.003296      -0.0     0.0
# 2008-01-09  1.476949  1.473490       0.0  0.009802       0.0     0.0
# 2008-01-10  1.476949  1.473490       0.0 -0.001832      -0.0     0.0
# ...              ...       ...       ...       ...       ...     ...
# 2020-12-23  1.211466  1.201682       0.0 -0.000057      -0.0     0.0
# 2020-12-27  1.211466  1.201682       0.0  0.002484       0.0     0.0
# 2020-12-28  1.211649  1.201831       0.0  0.002861       0.0     0.0
# 2020-12-29  1.214323  1.203993       0.0  0.004057       0.0     0.0
# 2020-12-30  1.214323  1.203993       0.0 -0.006885      -0.0     0.0
#
#             strategy_net  creturns  cstrategy  cstrategy_net
# 2008-01-06          -0.0  0.996535   1.000000       1.000000
# 2008-01-07           0.0  0.997376   1.000000       1.000000
# 2008-01-08          -0.0  0.994094   1.000000       1.000000
# 2008-01-09           0.0  1.003886   1.000000       1.000000
# 2008-01-10          -0.0  1.002048   1.000000       1.000000
# ...                  ...       ...        ...            ...
# 2020-12-23          -0.0  0.826291   1.239926       1.225773
# 2020-12-27           0.0  0.828346   1.239926       1.225773
# 2020-12-28           0.0  0.830719   1.239926       1.225773
# 2020-12-29           0.0  0.834096   1.239926       1.225773
# 2020-12-30          -0.0  0.828373   1.239926       1.225773
#
# [3807 rows x 17 columns]

# %%
data[["creturns", "cstrategy", "cstrategy_net"]].plot(figsize = (12 , 8))
plt.show()

# %%
data.loc["2018", ["creturns", "cstrategy", "cstrategy_net"]].plot(figsize = (12 , 8))
plt.show()
